# %% [markdown]
# # 1. we work with python numbers

# %%
5
# Out:
# 5

# %%
 5+6+7-2*3
# Out:
# 12

# %%
6+7-(3*4)-(7*3) #bodmas rule will apply.
# Out:
# -20

# %%
4 + 3
# Out:
# 7

# %%
a=3 # memories are saved a=3,b=5
b=5

# %%
int.__add__(a,b) # addition
# Out:
# 8

# %%
int.__sub__(a,b) # substraction
# Out:
# -2

# %%
int.__mul__(a,b) # multiplication
# Out:
# 15

# %%
int.__truediv__(a,b) # division with decimals
# Out:
# 0.6

# %%
int.__floordiv__(a,b) #division without decimals
# Out:
# 0

# %%
int.__pow__(a,b) #power
# Out:
# 243

# %%
c = 'Srushti'
d = 'Thakur'

# %%
str.__add__(c,d) #string as its name
# Out:
# 'SrushtiThakur'

# %% [markdown]
# # 2. work with text (string)

# %%
# in python text is always written in '',"",''' '''.

# %%
'Srushti Thakur'
# Out:
# 'Srushti Thakur'

# %%
"Srushti Thakur"
# Out:
# 'Srushti Thakur'

# %%
'''Srushti Thakur'''
# Out:
# 'Srushti Thakur'

# %%
# single quotes and double quotes -- single line

# %%
# triple quotes -- multiline comments will help in ai programs

# %% [markdown]
# # 3. Python Variable

# %%
v = 3
v
# Out:
# 3

# %%
id(v) # address of the memory location
# Out:
# 140733434016744

# %%
nit = 8 #case sensitive 
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 nit = 8
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit = 8
nit
# Out:
# 8

# %%
8 = 'nit' # cannot assign, variable doesn't start with digit but it can end with digit
# Out:
#   Cell In[44], line 1
#     8 = 'nit'
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
nit8 = 10 # this is how it ends with digit
nit8
# Out:
# 10

# %%
nit$ = 8, #special character is not allowed
# Out:
#   Cell In[48], line 1
#     nit$ = 8,
#        ^
# SyntaxError: invalid syntax

# %%
nit_ = 14
nit_
# Out:
# 14

# %%
import keyword
keyword.kwlist #keywords once done we will be done with python
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
def = 55 #keyword is not allowed as variable 
def
# Out:
#   Cell In[52], line 1
#     def = 55
#         ^
# SyntaxError: invalid syntax

# %%
DEF = 50 #Case sensitive 
DEF
# Out:
# 50

# %%
if=50 #keyword is not allowed as variable 
if
# Out:
#   Cell In[54], line 1
#     if=50
#       ^
# SyntaxError: invalid syntax

# %%
IF = 50 #Case sensitive 
IF
# Out:
# 50

# %% [markdown]
# 1. variables are case sensitive
# 2. keywords or reserved words cannot be variable
# 3. special character is not allowed
# 4. variable doesn't start with digit but can end with digit
# 5. only _ is allowed
# 6. python function ends with ().
#
# # python variables  are completed
#
# python variable = value
# values are called data types as well
# - int
# - float
# - string
# - bool
# - complex

# %%
3 + 4 
7 + 7
4 - 1 #it only gives the out of the recent input that we give to recall all the inputs data you need to call the function as below
# Out:
# 3

# %%
print(3+4)
print(7+7)
print(4-1) #this is why its important
# Out:
# 7
# 14
# 3

# %%
#when you want to print only one output print is not required else you need print.

# %%
5**3
# Out:
# 125
