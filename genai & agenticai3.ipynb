# %% [markdown]
# # 2. Python typecasting
# - cast from all data type to one data type
# - Typecasting can't be done from complex and text string to int and float
# - bool can't typecast the complex but it can typecast the string but only to true and only 1 parameter not more than 1
# - in bool if the function is empty it takes it as false. if anything apart from 0 it takes as true
# - we cannot give more than 1 aurgument in the function apart from complex.
# - in complex 2 parameters are allowed as real and imajinary part, it cant allow more than 2
# - in complex number string is allowed but text string is not allowed
# - complex takes only 1 parameter in number string it doesn't take more than 1
# - we can typecast the other datatype to string.

# %%
int(100.3) #covert float to int
# Out:
# 100

# %%
int(True) #covert boolen to int
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(10+20j) #complex to int is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(10+20j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int(100.3,200.3) #in typecasting only one aurgument is done not more than 1.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int(100.3,200.3)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int('10')
# Out:
# 10

# %%
int('ten') #when string is in text it cannot be passed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
# cast other data type to float

# %%
float(25) #int to float
# Out:
# 25.0

# %%
float(True) #bool to float
# Out:
# 1.0

# %%
float(False) #bool to float
# Out:
# 0.0

# %%
float(10+20j) #complex to float is not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float(10+20j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('8.0') #string with number to float is allowed
# Out:
# 8.0

# %%
# cast other data type to bool

# %%
bool(1) #int to bool is allowed
# Out:
# True

# %%
float('eight') #string with text to float is not allowed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 float('eight')
#
# ValueError: could not convert string to float: 'eight'

# %%
bool(0) #int to bool is allowed
# Out:
# False

# %%
bool(8,10j) #complex to bool is not allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 bool(8,10j)
#
# TypeError: bool expected at most 1 argument, got 2

# %%
bool('10') #string number to bool is allowed but it only converts to true
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(10+20j)
# Out:
# True

# %%
bool('100') #string number to bool is allowed but it only converts to true
# Out:
# True

# %%
bool('ten') #string text to bool is allowed but it only converts to true
# Out:
# True

# %%
bool('eight') #string text to bool is allowed but it only converts to true
# Out:
# True

# %%
bool('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 bool('10','20')
#
# TypeError: bool expected at most 1 argument, got 2

# %%
# cast other data type to complex

# %%
complex(8) #int to complex
# Out:
# (8+0j)

# %%
complex(8,10) # here in complex 2 parameters are allowed
# Out:
# (8+10j)

# %%
complex(8,10,12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 complex(8,10,12)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(5.2) #float to complex
# Out:
# (5.2+0j)

# %%
complex(5.2, 2.2) #float to complex with 2 parameters
# Out:
# (5.2+2.2j)

# %%
complex(True) #bool to complex
# Out:
# (1+0j)

# %%
complex(False) #bool to complex
# Out:
# 0j

# %%
complex('10') #number string is allowed
# Out:
# (10+0j)

# %%
complex('ten') #text string to complex is not allowed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex('20','10') #2 parameters of num string is not allowed to convert it to complex
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 complex('20','10')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('10',5) #2 parameters of num string is not allowed to convert it to complex
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 complex('10',5)
#
# TypeError: complex() can't take second arg if first is a string

# %%
# cast other data type to string

# %%
str(2) #int to string
# Out:
# '2'

# %%
str(2.5) #float to string
# Out:
# '2.5'

# %%
str(True) #bool to string
# Out:
# 'True'

# %%
str('False') #bool to string
# Out:
# 'False'

# %%
str(10+20j) #complex to string
# Out:
# '(10+20j)'

# %%
str(True, False) #2 parameters can't be converted to string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 str(True, False)
#
# TypeError: str() argument 'encoding' must be str, not bool

# %% [markdown]
# # 3. print() function
# - print is used for answers
# - it can print multiple parameters or aurguments.
# - we can use variable as an aurgument in print function
# -

# %%
print(10) #1 arg
print(10, 20) #2 arg
print('hello') #string arg
print(10, 20, 'srushti') #multiple arg
# Out:
# 10
# 10 20
# hello
# 10 20 srushti

# %%
num1 = 10
num2 = 20 #or num1, num2= 10, 20
add=num1+num2
print(add)
# Out:
# 30

# %%
#print result with string

# %%
print('The addition of', num1, 'and', num2 ,'=', add)
# Out:
# The addition of 10 and 20 = 30

# %%
name='Srushti'
age = 29
city = 'Florida'
print('my name is', name, 'i am', age, 'years old','i stay in',city)
# Out:
# my name is Srushti i am 29 years old i stay in Florida

# %%
#print format method
#Variables are not in {} but we define {} for the variable

# %%
num1, num2=10, 20
add = num1 + num2
print('the addition of {} and {} is= {}'.format(num1,num2,add))
#number of variables = number of flower bracer
# Out:
# the addition of 10 and 20 is= 30

# %%
num1, num2, num3=10,20,30
add=num1+num2+num3
print('the addition of {} and {} and {} is = {}'.format(num1,num2,num3,add))
# Out:
# the addition of 10 and 20 and 30 is = 60

# %%
#here var is euqal to braces 
name= 'Srushti'
age = 29
city = 'Florida'
work = 'AI Engineer'
print('Hi, my name is {} and i am {} years old currently living in {} and i am an {}, thankyou'.format(name, age, city, work))
# Out:
# Hi, my name is Srushti and i am 29 years old currently living in Florida and i am an AI Engineer, thankyou

# %%
num1 = 10
num2 = 20
num3 = 30
avg=(num1+num2+num3)/3
print('the average of {},{} and {} is = {})'.format(num1,num2,num3,avg))
# Out:
# the average of 10,20 and 30 is = 20.0)

# %%
#f - string
#variables should be in curly braces {var}

# %%
num1 = 10
num2 = 20
add=num1+num2
print(add)
# Out:
# 30

# %%
num1 , num2= 10, 20
add=num1+num2
print(f'the addition of {num1} and {num2} is = {add}') # variables are in curly braces #f difines f string method for print
# Out:
# the addition of 10 and 20 is = 30

# %%
# var is within braces in f string
name= 'Srushti'
age = 29
city = 'Florida'
work = 'AI Engineer'
print(f'Hi, my name is {name} and i am {age} years old currently living in {city} and i am an {work}, thankyou')
# Out:
# Hi, my name is Srushti and i am 29 years old currently living in Florida and i am an AI Engineer, thankyou

# %%
#end statement
#here we will use end statement that join line from end of one string to starting of other string

# %%
print('hello')
print('good morning') # here the statement is not in 1 line to get them in one line we use end
# Out:
# hello
# good morning

# %%
print('hello', end='') #1st statement 
print('good morning') #2nd statement
# Out:
# hellogood morning

# %%
print('*')
print('***', end='-') #end the line here 
print('****')
# Out:
# *
# ***-****

# %%
#seprator 
#when we want to seperate the values we use this

# %%
print('hi', 'hello', 'how are you?', sep='--->')
# Out:
# hi--->hello--->how are you?

# %%
print('hi', 'hello', 'how are you?', sep='-*-')
# Out:
# hi-*-hello-*-how are you?

# %%
print(1,end='-')
print(2,end='-')
print(3,sep='')
# Out:
# 1-2-3

# %%
print('hello',end='', 'hi',end='') #not possible
# Out:
#   Cell In[96], line 1
#     print('hello',end='', 'hi',end='')
#                                      ^
# SyntaxError: positional argument follows keyword argument
