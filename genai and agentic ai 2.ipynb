# %% [markdown]
# # Python Datatype

# %%
i = 56
i
# Out:
# 56

# %%
type(i) #value without decimal is called int. eg 56 is int
# Out:
# int

# %%
f = 3.15
f
# Out:
# 3.15

# %%
type(f) #value with decimal is called float. eg 3.15 is float
# Out:
# float

# %%
f1 = 1e0 #e0-1.0 e1-10.0 e2-100.0
f1
# Out:
# 1.0

# %%
f2 = 2.3e2 #e is exponential
f2
# Out:
# 230.0

# %%
f3 = 2.3e3
f3
# Out:
# 2300.0

# %%
b = True #boolen is True or False, you have to make sure T and F are capital and for None 'N'
b
# Out:
# True

# %%
b1 = False
b2 = True
b1 + b2
# Out:
# 1

# %%
print(b1+b2)
print(b1-b2)
print(b1*b2)
# Out:
# 1
# -1
# 0

# %%
False / True #float division
# Out:
# 0.0

# %%
False // True #int division
# Out:
# 0

# %%
True/False #1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
#complex-- only in python we have this type of datatype 
#Syntax- a+bj (only j letter is allowed)
#a=real part,b=imaginary part and j=square root of -1
#complex is used in big math problems

# %%
c = 10+20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c1=30+2.2j
c1
# Out:
# (30+2.2j)

# %%
c2=2.2+30j
c2
# Out:
# (2.2+30j)

# %%
c1 + c2 #system will automatically add real part to real that why python is called dynamic language
# Out:
# (32.2+32.2j)

# %%
#String

# %%
S = 'Srushti'
S
# Out:
# 'Srushti'

# %%
type(S)
# Out:
# str

# %%
S[0] #forward index
# Out:
# 'S'

# %%
S[-1] #backward index
# Out:
# 'i'

# %%
S[:] #print all element  ':' used in slice
# Out:
# 'Srushti'

# %%
  S[2:] #after 2nd index it will be printed
# Out:
# 'ushti'

# %%
S
# Out:
# 'Srushti'

# %%
S[:5] # from 0 to 4(n-1) will be printed
# Out:
# 'Srush'

# %%
S
# Out:
# 'Srushti'

# %%
S[0:6:2] #forward index starts with 0, doesnt include 6 and keep jumping ever 2 index
# Out:
# 'Suh'

# %%
S
# Out:
# 'Srushti'

# %%
S[1:7:4]
# Out:
# 'rt'

# %%
S[-3] #backward index
# Out:
# 'h'

# %%
S[:-3]
# Out:
# 'Srus'

# %%
S[-3:]
# Out:
# 'hti'

# %%
S[-1:-5:-2]
# Out:
# 'ih'

# %%
S[2:-2]
# Out:
# 'ush'

# %%
S
# Out:
# 'Srushti'

# %%
S[2:-2:3] ### doubt need to be clarified
# Out:
# 'u'

# %%
movie = '''Kantara (2022) is an Indian Kannada-language action-drama film written, directed by, and starring Rishab Shetty.
It became one of the biggest cultural and box-office sensations in Indian cinema due to its authentic portrayal of folklore, powerful performances, and intense climax.'''

# %%
movie
# Out:
# 'Kantara (2022) is an Indian Kannada-language action-drama film written, directed by, and starring Rishab Shetty.\nIt became one of the biggest cultural and box-office sensations in Indian cinema due to its authentic portrayal of folklore, powerful performances, and intense climax.'

# %%
print(3 + 2)
# Out:
# 5

# %%
print(3-2)
# Out:
# 1

# %%
print(3*2)
# Out:
# 6

# %%
print(3/2)
# Out:
# 1.5

# %%
print(3**2)
# Out:
# 9

# %%
print(3%2)
# Out:
# 1

# %%
print(3//2)
# Out:
# 1

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print(type(10.33))
# Out:
# <class 'float'>

# %%
print(type(10+6j))
# Out:
# <class 'complex'>

# %%
print(type('Srushti'))
# Out:
# <class 'str'>

# %%
print(type([1,2,3,4]))
# Out:
# <class 'list'>

# %%
print(type({'name':'Thakur'}))
# Out:
# <class 'dict'>

# %%
print(type({9.8,5.2,7.2}))
# Out:
# <class 'set'>

# %%
print(type((9.8,5.2,7.2)))
# Out:
# <class 'tuple'>

# %%
print(type(3==3))
# Out:
# <class 'bool'>

# %%
print(type(3>=3))
# Out:
# <class 'bool'>
